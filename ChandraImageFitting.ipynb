# %% [markdown]
# ## A quick Poisson fitting tutorial in python
#
# Requires:
# - numpy
# - scipy
# - matplotlib
# - (emcee; if MCMC is something you're interested in)
#
#
# Data from the Chandra X-ray Satellite comes as images. These images are photon counting data, that is each pixel records an integer number of photons.
# Data of this kind follows a Poisson distribution, that is, if there was no signal (i.e. only background noise), the resulting photons would follow a Poisson distribution with a single parameter (the background rate). This means that the value in each pixel $y$ is picked from the following distribution:
#
# $$P(y|\lambda) = \frac{e^{-\lambda}\lambda^{y}}{y!}$$ ,
#
# where $\lambda$ is the model parameter describing the expected count rate.
#
# The function we are interested in is the *likelihood* of the data. The likelihood describes the probability of observing the data we've measured, conditioned on a *physical* model (your surface brightness model) and a *statistical* model (the Poisson distribution). The physical model describes what you expect your image to look like if there was no noise. The statistical model describes the uncertainty in the measurements because there is noise present.
# The likelihood function is the product of the probabilities of all pixels, which is the probability of observing a number of counts in a pixel, $y_i$ under the assumption of a model count rate in that same pixel, $m_i$, multiplied together for all $N$ pixels.
#
# All in all, the Poisson likelihood for a given physical model $m(\mathbf{\theta})$, which depends on a set of $K$ parameters $\mathbf{\theta} = \{\theta_1, \theta_2, ... , \theta_k\}$ looks like this:
#
# $$L(\mathbf{\theta}) = P(\mathbf{y}|\mathbf{\theta}, H) = \prod_{i=0}^N{(\frac{e^{-m_i(\mathbf{\theta})}m_i(\mathbf{\theta})^{y_i}}{y_i!})}$$
#
# The "best fit" parameters of your physical models are those that maximise the likelihood. In practical terms, the likelihood is often very large, and it is more convenient to maximise the logarithm of the likelihood. Because it is also easier for numerical reasons to minimise a function instead of maximising it, in practice you want to minimise the -log-likelihood, i.e. this quantity:
#
# $$
# -\log{(L(\mathbf{\theta})} = \sum_{i=0}^{N}{(-m_i(\mathbf{\theta}) + y_i\log{(m_i(\mathbf{\theta}))} - \log{(y_i!)}    )}
# $$
#
# You can separate out the various sums, and the logarithm of $y_i!$ becomes a $\Gamma$-function, which is in `scipy.special`.
#
# Below is some simple code for the Poisson likelihood of a given model and a stupidly simple example. Because I don't have image data, below I've used a lightcurve, but the whole thing should generalise easily to 2D and a more complicated model.
#
# First, let's make some fake data. For now, this data is just a flat light curve of 1000 seconds duration and a time resolution of 1 second, with a background count rate of 10 counts/s.

# %%
import numpy as np
import scipy.stats
import scipy.optimize

## step 1: make some fake data, just a flat light curve with a 
## background parameter of 10

# time array
times = np.arange(0,1000,1)

# data array, pick from a Poisson distribution with mean rate=10
counts = np.random.poisson(10, size=len(times))

# %% [markdown]
# Next, let's define the model for what the background should be. In our case, it's just a flat background with a single parameter that describes the background count rate (which, at this point, we pretend we don't know).

# %%
## function that describes the model
## this could have more parameters if your model is more complex
def mymodel(times, rate_par):
    ## this can be as complex as you like
    model_counts = np.ones(len(times))*rate_par
    return model_counts

# %% [markdown]
# Now we've got some data and we've got a physical model ("only background counts of an unknown flux") we'd like to use to describe this data. Now we need to define the Poisson likelihood, i.e. our statistical model.

# %%
## this is the positive log-likelihood
## you can derive this easily from the definition of the poisson distribution
## rate is the 
def poisson_loglike(counts, model_counts):
    ## now we can compute the log-likelihood:
    llike = -np.sum(model_counts) + np.sum(counts*np.log(model_counts))-np.sum(scipy.special.gammaln(counts + 1))
    return llike

# %% [markdown]
# Now we can put the two together and compute the thing we actually want to minimise. This is also often called the *deviance*, for unknown (to me) reasons:

# %%
## model is the function that describes the physical model
## parameters is a list with parameters (one or more)
## times and counts are the data
def deviance(model, parameters, times, counts):
    model_counts = model(times, *parameters)
    return -2.*poisson_loglike(counts, model_counts)

# %% [markdown]
# This you can now feed into a minimisation algorithm. But actually,
# it's much easier and more convenient to put all of this stuff into a small simple class like this:

# %%
logmin = 1000000000000.

class PoissonPosterior(object):
    ### x,y = Data
    ### func = physical model
    def __init__(self, x, y, func):
        self.x = x
        self.y = y

        ### func is a parametric model
        self.func = func

        return
    
    #def logprior(self, t0):
        
        ## THIS IS JUST AN EXAMPLE! WE NEED TO CHANGE THIS SO IT 
        ## ACTUALLY DOES THE RIGHT THING
        
        ## say background is t0[0]
    #    bkg  = t0[0]
    #    pbkg = bkg > 0
        
        ## this parameter can span a large range, so we're going to pick
        ## from the log-parameter because picking in linear space puts 
        ## undue weight to large values of the parameter. This is particularly
        ## useful to do for so-called scale parameters (like normalisation parameters etc.)
        #alpha = np.log(t0[1])
        #alpha_limits = [-10., 10.]
        
        ## probability of alpha is 1 if alpha is in range alpha_limits, 0 otherwise
        #palpha = (alpha >= alpha_limits[0] and alpha <= alpha_limits[1])
        
        ## third parameter is known to be around 1, 
        ## we pick a normal distribution with mean 1. and variance 0.1
        #beta = t0[2]
        #pbeta = scipy.stats.norm.pdf(beta, 1.0, 0.1)

    
        ## assuming all parameters are independent, we can multiply together 
        ## the individual probabilities for all parameters:
        #lp = pbkg*palpha*pbeta
    #    lp = pbkg
    #    return np.log(lp)
    
    def loglikelihood(self, t0):
        ## compute model counts
        model_counts = self.func(self.x, *t0)

        ## compute Poisson likelihood
        loglike = -np.sum(model_counts) + np.sum(self.y*np.log(model_counts))\
                    -np.sum(scipy.special.gammaln(self.y + 1))

        ## deal with NaN and inf values of the log-likelihood
        ## if either of these is true, choose a ridiculously small value
        ## to make the model *really* unlikely, but not infinite
        if np.isnan(loglike):
            loglike = -logmin
        elif loglike == np.inf:
            loglike = -logmin

        #print("loglikelihood: " + str(loglike))
        return loglike

    def logposterior(self, t0):
        print("t0: " + str(t0))
        print("log prior: " + str(self.logprior(t0)))
        print("log likelihood: " + str(self.loglikelihood(t0)))
        lpost = self.loglikelihood(t0) + self.logprior(t0)
        print("log posterior: " + str(lpost))
        return lpost 
    
    def __call__(self, t0, neg=False):
        lpost = self.logposterior(t0) 

        ## the negative switch makes sure you can call both
        ## the log-likelihood, and the negative log-likelihood
        if neg == True:
            return -lpost
        else:
            return lpost

# %% [markdown]
# The class structure sets this problem up in a convenient way for fitting. Below, we're just plotting some guesses for the likelihood function to see how it changes with different values for the parameter. As you should be able to see, it gets larger (less negative) as we get closer to the true value of the rate (i.e. 10).

# %%
## define PoissonLikelihood object:
pl = PoissonPosterior(times, counts, mymodel)


## print the likelihood function for some guesses to see its behaviour:
guesses = [[5.], [7.], [10.], [15.], [20.]]
for g in guesses:
    print(pl(g, neg=False))
# Out:
# t0: [5.0]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-3dd5299a5efa> in <module>()
#       6 guesses = [[5.], [7.], [10.], [15.], [20.]]
#       7 for g in guesses:
# ----> 8     print(pl(g, neg=False))
#       9
#
# <ipython-input-3-ebe15994c251> in __call__(self, t0, neg)
#      71
#      72     def __call__(self, t0, neg=False):
# ---> 73         lpost = self.logposterior(t0)
#      74
#      75         ## the negative switch makes sure you can call both
#
# <ipython-input-3-ebe15994c251> in logposterior(self, t0)
#      64     def logposterior(self, t0):
#      65         print("t0: " + str(t0))
# ---> 66         print("log prior: " + str(self.logprior(t0)))
#      67         print("log likelihood: " + str(self.loglikelihood(t0)))
#      68         lpost = self.loglikelihood(t0) + self.logprior(t0)
#
# AttributeError: 'PoissonPosterior' object has no attribute 'logprior'

# %% [markdown]
# Now let's do some actual fitting using scipy.optimize:

# %%
    
## define your fit method of choice, look at documentation of scipy.optimize for details
## let's use the BFGS algorithm for now, it's pretty good and stable, but you can use others
## note that the output will change according to the algorithm, so check the documentation
## for what your preferred algorithm returns
fitmethod = scipy.optimize.fmin_bfgs

    
## set neg=True for negative log-likelihood

neg = True

initial_guess = [5.]
## do the actual fit
popt, fopt, gopt, covar, func_calls, grad_calls, warnflag  = fitmethod(pl, initial_guess, args=(neg,), full_output=True)

## popt are the optimum parameter values
## fopt is the likelihood function at optimum
## gopt is the value of the minimum of the gradient of the likelihood function
## covar is the inverse Hessian matrix, can be used for error calculation
## func_calls: number of function calls made
## grad_calls: number of calls to the gradient

print("Optimum parameter values: " + str(popt))
print("Likelihood at optimimum parameter values: " + str(fopt))
# Out:
# Optimization terminated successfully.
#          Current function value: 2580.622539
#          Iterations: 6
#          Function evaluations: 30
#          Gradient evaluations: 10
# Optimum parameter values: [ 9.9589988]
# Likelihood at optimimum parameter values: 2580.62253868

# %%
if warnflag == 1:
    print("Maximum number of iterations exceeded")
elif warnflag == 2:
    print("Gradient and/or function calls not changing")
else:
    print("No clue")
# Out:
# No clue

# %% [markdown]
# The returned value `bopt` is what we call the inverse of the Hessian matrix. The Hessian matrix is the matrix of second derivatives of the likelihood function with respect to each parameter in the model. This is computed numerically by the algorithm doing the fitting.
# One can show that the inverse of this matrix, called the *covariance matrix*, describes the variances and covariances between parameters (i.e. how much they vary with themselves, and with each other parameter). This tells you something about the uncertainty in the parameters (via the variance) and how much they correlate  with each other (the covariances).
# You can compute the standard errors on your parameters by taking the square-root of the diagonal of this matrix (the square root of the variances):

# %%
stderr = np.sqrt(np.diag(covar))
print("standard error on the parameters: " + str(stderr))
# Out:
# standard error on the parameters: [ 0.09987924]

# %% [markdown]
# In our stupid simple example, there's only one parameter, so only one element in the inverse Hessian matrix. If you have two parameters, this matrix will have four elements, for three parameters 9 elements and so forth.
#
# I'm still working on what the right statistic would be for testing the goodness-of-fit. I will add this when I've figured out what the most appropriate choice would be.
#
#
# ## MCMC for this problem using *emcee*
#
# Markov Chain Monte Carlo is a powerful technique to recover complex probability distributions. For example, imagine your negative log-likelihood function has two minima for a given parameter. In this case, the fitting algorithm may end up at one minimum or another, depending on the starting value, and you will never know about the other. Or, imagine that your errors are skewed: your estimate may be much more uncertain in one direction than another. In this case, your standard errors will not reflect reality very well.
# In this case, it can be useful to *sample* the probability distribution instead of fit it in order to retain enough information about the distribution to make useful estimates.
#
# This is not an intro into MCMC, but there are many good tutorials out there. If you'd like to learn about MCMC, I'd recommend to write your own Metropolis-Hastings sampler.
#
# Below, I'll be using an out-of-the-box, very stable and well-written code called *emcee* to run MCMC on the likelihood above. This may take a while to run, depending on the number of data points and the complexity (number of parameters) of your model

# %%
import emcee

## number of walkers in emcee
## should be large (>100)
nwalkers = 500

### number of dimensions for the Gaussian seeds (= number of parameters)
ndim = len(popt)

### sample random starting positions for each of the walkers
p0 = [np.random.multivariate_normal(popt,covar) for i in xrange(nwalkers)]

### initialize sampler
sampler = emcee.EnsembleSampler(nwalkers, ndim, pl, args=[False])

### run burn-in phase and reset sampler
burnin_samples = 200
pos, prob, state = sampler.run_mcmc(p0, burnin_samples)
sampler.reset()


### run actual MCMCs
niter = 100
sampler.run_mcmc(pos, niter, rstate0=state)

### list of all samples stored in flatchain
mcall = sampler.flatchain

### print meanacceptance rate for all walkers and autocorrelation times
print("The ensemble acceptance rate is: " + str(np.mean(sampler.acceptance_fraction)))
L = np.mean(sampler.acceptance_fraction)*len(mcall)
acceptance = np.mean(sampler.acceptance_fraction)
#try:
#    self.acor = sampler.acor
#    print("The autocorrelation times are: " +  str(sampler.acor))
#except ImportError:
#    print("You can install acor: http://github.com/dfm/acor")
#    self.acor = None
#except RuntimeError:
#    print("D was negative. No clue why that's the case! Not computing autocorrelation time ...")
#    self.acor = None
#except:
#    print("Autocorrelation time calculation failed due to an unknown error: " + sys.exc_info()[0] + ". Not computing autocorrelation time.")
#    self.acor = None
# Out:
# The ensemble acceptance rate is: 0.80276

# %% [markdown]
# `mcall` is a list of parameter values. You can make a histogram of it to see the distribution of your parameter(s).

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.hist(mcall[:,0], bins=30);

# %% [markdown]
# For multi-parameter problems, you can make a matrix plot that plots scatter plots for each parameter against each other parameter, and histograms for each parameter individually. This is a tremendously useful diagnostic tool in determining whether your distributions are skewed, or whether there are significant correlations between parameters.
#
# Here's code for the matrix plot. It makes a simple scatter plot like the one above in the case of a one-parameter model, and a matrix plot for a model with several parameters.

# %%
## function that makes the scatter plot
def scatter_plot(samples, ndims):
    fig, axes = plt.subplots(ndims,ndims,figsize=(15,15))

    ### for one-parameter model, make scatter plot
    if ndims == 1:
        axes.hist(samples, bins=20)
        
    ### for more than one parameter, make matrix plot
    else:
        for i in xrange(ndims): ## x dimension
            for j in xrange(ndims): ## y dimension
                if i == j: 
                    axes[i,j].hist(samples[:,i], bins=20)
                else:
                    axes[i,j].scatter(samples[:,i], samples[:,j], color="black")

    return


## number of dimensions for the plot = number of parameters
ndims = mcall.shape[1]

## number of MCMC samples
nsamples = mcall.shape[0]

## make scatter plot for real model:
scatter_plot(mcall, ndims)

# %% [markdown]
# In order to see the scatter plot properly, below I will make some random multi-dimensional samples. Imagine these are MCMC samples from a model with four parameters. I'm using a multi-variate Gaussian distribution for convenience.

# %%
means = [1,2,6,4]
covariances = [[3,2,1,3],[1,2,1,4], [1,2,3,2], [3,1,3,1]]
    
rand_data = np.random.multivariate_normal(means, np.array(covariances), size=100)
ndims = rand_data.shape[1]

scatter_plot(rand_data, ndims)
# Out:
# -c:5: RuntimeWarning: covariance is not positive-semidefinite.

# %% [markdown]
# Note that the top and the bottom are mirrored: the scatter plot in the top row, second column is the same as the second row, first column plot (i.e. we're making scatter plots of the same parameters against each other), just mirrored. You can see that some parameters have strong correlations. The histograms all look quite Gaussian, but this is because I put in Gaussian distributions to simulate the samples.
#
# The advantage of MCMC is that you can easily make simulations from the samples you drew from the model. This can be quite useful when you'd like to, for example, make sure the errors in your parameter estimation are properly accounted for in whatever final result you're interested in (I guess in your case, the cavity regions in the image).
# The basic procedure works like this:
# - randomly pick a parameter set from your MCMC sample
# - make an image from that model
# - for each pixel in this image, pick from a Poisson distribution where the distribution's parameter $\lambda$ is the pixel value derived from your model. We're going to pretend that this is data (without cavity)
# - run whatever cavity detection procedure you use on this simulated image and compute whatever final result you're interested in
# - repeat these four steps many (say, 1000$ times
# - compare the numbers derived from your simulations to that from your real observed image. If the numbers are very similar, you probably don't have a cavity. If they are very different, either there's something real there or your background model is wrong.
#
# If you're interested in this sort of stuff, let me know and we can talk about it in more detail.
#
#
#
#
# ## Poisson Fitting with Images
#
# Next step, let's try this with images.
#
# I'm going to fiddle with Martijn's code a bit to figure out what's going on there.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from astropy.io import fits
import numpy as np
import scipy
from scipy import special

# %%
hdulist = fits.open("2a0335_core_flux.fits")
hdu_in = hdulist[0]
sb_data  = hdu_in.data
in_header = hdu_in.header

# %%
plt.imshow(sb_data)

# %%
xdata = np.meshgrid(np.linspace(0,len(sb_data), num=len(sb_data)),np.linspace(0,len(sb_data),num=len(sb_data)))

# %%
print(xdata[0][-1,0])
# Out:
# 0.0

# %%
## The ellipse model
def ellipse_model(x, cp_x, cp_y, q, a, phi, logScool, rcool, betacool, logbackground):

    q = np.exp(q)
    Scool = np.exp(logScool)
    background = np.exp(logbackground)

    theta = np.arctan2(x[1] - cp_x , x[0] - cp_y)
    radius = np.sqrt((x[0]-cp_x)**2 + ((x[1]-cp_y)/q)**2) * ( 1 + (a * np.cos(theta + phi)))
    profile = Scool*(1 + (radius/rcool) **2.)**(0.5 - 3*betacool) + background

    return profile

# %%
## let's make an example
pr = ellipse_model(xdata, 400, 400, 0.0, 0.2, 1.*np.pi, 1.0, 100.0, 1.0, -1.0)
print(pr.shape)
plt.imshow(pr)
# Out:
# (801, 801)

# %% [markdown]
# Let's define a Posterior for this model:

# %%
class PoissonImagePosterior(PoissonPosterior, object):
    
    def logprior(self, t0):
        #print("I am in the right logprior")
        #x, cp_x, cp_y, q, a, phi, logScool, rcool, betacool, logbackground
        
        ## dumbest priors possible: set by the boundaries of the image.
        
        ## first two parameters are center pixels
        cpx = t0[0]
        cpy = t0[1]
        
        ## center pixel needs to be within the image
        p_cpx = (cpx >= self.x[0][0,0] and cpx <= self.x[0][-1,-1])
        p_cpy = (cpy >= self.x[0][0,0] and cpy <= self.x[0][-1,-1])
        #print("pixel priors: " + str(p_cpx) + ", " + str(p_cpy))
        
        ## ellipticity q
        q = t0[2]
        p_q = (q <= 0.)
        
        #print("ellipticity prior: " + str(p_q))

        ## displacement of the center
        a = t0[3]
        p_a = (a >= 0.0 and a < self.x[0][-1,-1])
        #print("displacement prior: " + str(p_a))
        
        ## angle:
        ## This is a dumb prior. I need to find a better prior for
        ## periodic boundary conditions
        phi = t0[4]
        p_phi = (phi >= 0.0 and phi <= 2.*np.pi)
        #print("angle prior: " + str(p_phi))
        
        ## Surface brightness of the core:
        ## flat in log-space translates to 1/S prior in real space
        logscool = t0[5]
        p_logscool = (logscool >= -21. and logscool <= -5.)
        #print("surface brightness prior: " + str(p_logscool))
        
        #x, cp_x, cp_y, q, a, phi, logScool, rcool, betacool, logbackground

        ## core radius:
        ## dumb prior: radius needs to be smaller than 2*the image size
        rcool = t0[6]
        p_rcool = (rcool > 0. and rcool <= 2.*self.x[0][-1,-1])
        #print("radius prior: " + str(p_rcool))
        
        ## beta parameter
        ## let's put an exponential prior on this:
        beta = t0[7]
        hyper_beta = 1.0 ## hyper parameter for the exponential prior
        if beta < 0.0:
            p_beta = 0.0
        else:
            p_beta = (1./hyper_beta)*np.exp(-beta/hyper_beta)
        #print("beta prior: " + str(p_beta))
        
        ## log background, same as core radius, but probably a dumb choice
        logbkg = t0[8]
        p_logbkg = (logbkg >= -21. and logbkg <= -5.)
        #print("background prior: " + str(p_logbkg))
        
        
        lp = p_cpx*p_cpy*p_q*p_a*p_phi*p_logscool*p_rcool*p_beta*p_logbkg
        #print("logprior: " + str(lp))
        
        if lp > 0:
           return np.log(lp)
        else:
           return -logmin
            #return -np.inf
        
    def logposterior(self, t0):
        #print("t0: " + str(t0))
        lprior = self.logprior(t0)
        #print("log prior: " + str(self.logprior(t0)))
        llike = self.loglikelihood(t0)
        #print("log likelihood: " + str(self.loglikelihood(t0)))
        lpost = lprior + llike
        #print("log posterior: " + str(lpost))
        return lpost 
    
    def __call__(self, t0):
        lpost = self.logposterior(t0) 

        ## the negative switch makes sure you can call both
        ## the log-likelihood, and the negative log-likelihood
        return lpost

# %%
lpost = PoissonImagePosterior(xdata, sb_data, func=ellipse_model)

# %%
mean_countrate = np.log(np.mean(sb_data))
max_countrate = np.log(np.max(sb_data[300:500, 300:500]))
print("The mean count rate is: " + str(mean_countrate))
print("The maximum count rate is: " + str(max_countrate))

#cp_x, cp_y, q, a, phi, logScool, rcool, betacool, logbackground
testpars = [400, 380, 0.1, 0.0, 1.*np.pi, max_countrate, 100. , 1.0, mean_countrate]

print("The prior probability of this parameter set is p = %.3f"%lpost.logprior(testpars))
print("The likelihood of this parameter set is p = %.3f"%lpost.loglikelihood(testpars))
print("The posterior of this parameter set is p = %.3f"%lpost.logposterior(testpars))
fit_profile = ellipse_model(xdata, *testpars)

fig = plt.figure(figsize=(10,20))
plt.subplot(2,1,1)
plt.imshow(sb_data)
plt.colorbar()
plt.subplot(2,1,2)
plt.imshow(fit_profile)
plt.colorbar()
# Out:
# The mean count rate is: -17.1746
# The maximum count rate is: -13.6257
# The prior probability of this parameter set is p = -1000000000000.000
# The likelihood of this parameter set is p = -0.388
# The posterior of this parameter set is p = -1000000000000.388
# <matplotlib.colorbar.Colorbar instance at 0x119dfdb48>

# %%
## define negative posterior
def negative_posterior(pars):
    neg_lp = -lpost.loglikelihood(pars)
    print("The posterior is " + str(neg_lp))
    return neg_lp

#fitmethod = scipy.optimize.fmin_l_bfgs_b
fitmethod = scipy.optimize.fmin_bfgs

bounds_cpx = (0, 800)
bounds_q = (-20, 0.)
bounds_a = (0, 400)
bounds_phi = (0, 2.*np.pi)
bounds_logscool = (-21., -5.)
bounds_rcool = (1., 800.)
bounds_betacool = (0.0, 5.)
bounds_logbkg = (-21., -5.)

bounds = [bounds_cpx, bounds_cpx, bounds_q, bounds_a, bounds_phi, bounds_logscool,
          bounds_rcool, bounds_betacool, bounds_logbkg]
#cp_x, cp_y, q, a, phi, logScool, rcool, betacool, logbackground
initial_guess = testpars


#results  = fitmethod(negative_posterior, initial_guess, bounds=bounds, approx_grad =True)
results  = fitmethod(negative_posterior, initial_guess, full_output=True)
# Out:
# The posterior is 0.387993917579
# The posterior is 0.387993917579
# The posterior is 0.387993917579
# The posterior is 0.387993917779
# The posterior is 0.387993917635
# The posterior is 0.387993917579
# The posterior is 0.387993917786
# The posterior is 0.387993917583
# The posterior is 0.387993917198
# The posterior is 0.387993917783
# The posterior is 0.387993917579
# The posterior is 0.386853605909
# The posterior is 0.386853605909
# The posterior is 0.386853605909
# The posterior is 0.386853605909
# The posterior is 0.386853606081
# The posterior is 0.386853605958
# The posterior is 0.386853605909
# The posterior is 0.386853606091
# The posterior is 0.386853605912
# The posterior is 0.386853605594
# The posterior is 0.386853606104
# The posterior is 0.384890406068
# The posterior is 0.384890406068
# The posterior is 0.384890406068
# The posterior is 0.384890406068
# The posterior is 0.384890406187
# The posterior is 0.384890406105
# The posterior is 0.384890406067
# The posterior is 0.384890406203
# The posterior is 0.38489040607
# The posterior is 0.384890405865
# The posterior is 0.384890406243
# The posterior is 0.382226579966
# The posterior is 0.382226579966
# The posterior is 0.382226579966
# The posterior is 0.382226579966
# The posterior is 0.382226579994
# The posterior is 0.382226579983
# The posterior is 0.382226579966
# The posterior is 0.382226580027
# The posterior is 0.382226579966
# The posterior is 0.382226579921
# The posterior is 0.382226580097
# The posterior is 0.381461450904
# The posterior is 0.381461450904
# The posterior is 0.381461450904
# The posterior is 0.381461450904
# The posterior is 0.381461450889
# The posterior is 0.381461450912
# The posterior is 0.381461450904
# The posterior is 0.381461450932
# The posterior is 0.381461450904
# The posterior is 0.381461450916
# The posterior is 0.381461451006
# The posterior is 0.38123710971
# The posterior is 0.38123710971
# The posterior is 0.38123710971
# The posterior is 0.38123710971
# The posterior is 0.381237109672
# The posterior is 0.381237109714
# The posterior is 0.381237109711
# The posterior is 0.381237109721
# The posterior is 0.381237109709
# The posterior is 0.381237109746
# The posterior is 0.381237109793
# The posterior is 0.381154743103
# The posterior is 0.381154743103
# The posterior is 0.381154743103
# The posterior is 0.381154743103
# The posterior is 0.381154743056
# The posterior is 0.381154743105
# The posterior is 0.381154743104
# The posterior is 0.381154743107
# The posterior is 0.381154743102
# The posterior is 0.381154743149
# The posterior is 0.381154743176
# The posterior is 0.381035235771
# The posterior is 0.381035235771
# The posterior is 0.381035235771
# The posterior is 0.381035235771
# The posterior is 0.381035235715
# The posterior is 0.381035235772
# The posterior is 0.381035235772
# The posterior is 0.381035235769
# The posterior is 0.38103523577
# The posterior is 0.381035235826
# The posterior is 0.381035235832
# The posterior is 0.380831844759
# The posterior is 0.380831844759
# The posterior is 0.380831844759
# The posterior is 0.380831844759
# The posterior is 0.380831844696
# The posterior is 0.380831844758
# The posterior is 0.380831844761
# The posterior is 0.380831844752
# The posterior is 0.380831844758
# The posterior is 0.380831844822
# The posterior is 0.380831844805
# The posterior is 0.380477430786
# The posterior is 0.380477430786
# The posterior is 0.380477430786
# The posterior is 0.380477430786
# The posterior is 0.380477430719
# The posterior is 0.380477430783
# The posterior is 0.380477430788
# The posterior is 0.380477430774
# The posterior is 0.380477430784
# The posterior is 0.380477430856
# The posterior is 0.380477430815
# The posterior is 0.379865750871
# The posterior is 0.379865750871
# The posterior is 0.379865750871
# The posterior is 0.379865750871
# The posterior is 0.379865750807
# The posterior is 0.379865750866
# The posterior is 0.379865750872
# The posterior is 0.379865750859
# The posterior is 0.379865750869
# The posterior is 0.379865750946
# The posterior is 0.379865750881
# The posterior is 0.378917412518
# The posterior is 0.378917412518
# The posterior is 0.378917412518
# The posterior is 0.378917412518
# The posterior is 0.378917412482
# The posterior is 0.378917412508
# The posterior is 0.378917412518
# The posterior is 0.378917412519
# The posterior is 0.378917412517
# The posterior is 0.378917412583
# The posterior is 0.378917412512
# The posterior is 0.378599971107
# The posterior is 0.378599971107
# The posterior is 0.378599971107
# The posterior is 0.378599971107
# The posterior is 0.378599971141
# The posterior is 0.378599971084
# The posterior is 0.378599971104
# The posterior is 0.37859997115
# The posterior is 0.378599971108
# The posterior is 0.378599971102
# The posterior is 0.378599971103
# The posterior is 0.378552228091
# The posterior is 0.378552228091
# The posterior is 0.378552228091
# The posterior is 0.378552228091
# The posterior is 0.3785522281
# The posterior is 0.378552228073
# The posterior is 0.378552228089
# The posterior is 0.378552228118
# The posterior is 0.378552228091
# The posterior is 0.378552228116
# The posterior is 0.378552228085
# The posterior is 0.378541798855
# The posterior is 0.378541798855
# The posterior is 0.378541798854
# The posterior is 0.378541798855
# The posterior is 0.378541798867
# The posterior is 0.378541798836
# The posterior is 0.378541798853
# The posterior is 0.378541798883
# The posterior is 0.378541798855
# The posterior is 0.378541798876
# The posterior is 0.378541798849
# The posterior is 0.37852245921
# The posterior is 0.37852245921
# The posterior is 0.37852245921
# The posterior is 0.37852245921
# The posterior is 0.378522459226
# The posterior is 0.378522459192
# The posterior is 0.378522459208
# The posterior is 0.378522459241
# The posterior is 0.37852245921
# The posterior is 0.378522459226
# The posterior is 0.378522459205
# The posterior is 0.378486673818
# The posterior is 0.378486673818
# The posterior is 0.378486673818
# The posterior is 0.378486673818
# The posterior is 0.378486673839
# The posterior is 0.378486673801
# The posterior is 0.378486673816
# The posterior is 0.378486673851
# The posterior is 0.378486673818
# The posterior is 0.378486673828
# The posterior is 0.378486673814
# The posterior is 0.378422510679
# The posterior is 0.378422510679
# The posterior is 0.378422510679
# The posterior is 0.378422510679
# The posterior is 0.378422510707
# The posterior is 0.378422510665
# The posterior is 0.378422510676
# The posterior is 0.378422510715
# The posterior is 0.378422510679
# The posterior is 0.378422510678
# The posterior is 0.378422510677
# The posterior is 0.378317533472
# The posterior is 0.378317533472
# The posterior is 0.378317533472
# The posterior is 0.378317533472
# The posterior is 0.378317533511
# The posterior is 0.378317533465
# The posterior is 0.37831753347
# The posterior is 0.378317533513
# The posterior is 0.378317533472
# The posterior is 0.378317533453
# The posterior is 0.378317533473
# The posterior is 0.378181690814
# The posterior is 0.378181690814
# The posterior is 0.378181690814
# The posterior is 0.378181690814
# The posterior is 0.378181690865
# The posterior is 0.378181690823
# The posterior is 0.378181690814
# The posterior is 0.378181690858
# The posterior is 0.378181690815
# The posterior is 0.378181690764
# The posterior is 0.378181690821
# The posterior is 0.378046908104
# The posterior is 0.378046908104
# The posterior is 0.378046908104
# The posterior is 0.378046908104
# The posterior is 0.378046908148
# The posterior is 0.378046908122
# The posterior is 0.378046908104
# The posterior is 0.37804690814
# The posterior is 0.378046908105
# The posterior is 0.37804690806
# The posterior is 0.378046908111
# The posterior is 0.377874014115
# The posterior is 0.377874014115
# The posterior is 0.377874014115
# The posterior is 0.377874014115
# The posterior is 0.377874014133
# The posterior is 0.37787401414
# The posterior is 0.377874014115
# The posterior is 0.377874014127
# The posterior is 0.377874014115
# The posterior is 0.377874014112
# The posterior is 0.377874014118
# The posterior is 0.377842951279
# The posterior is 0.377842951279
# The posterior is 0.377842951279
# The posterior is 0.377842951279
# The posterior is 0.37784295129
# The posterior is 0.377842951308
# The posterior is 0.37784295128
# The posterior is 0.377842951283
# The posterior is 0.377842951279
# The posterior is 0.377842951288
# The posterior is 0.377842951281
# The posterior is 0.377828044428
# The posterior is 0.377828044428
# The posterior is 0.377828044428
# The posterior is 0.377828044428
# The posterior is 0.377828044437
# The posterior is 0.377828044456
# The posterior is 0.377828044429
# The posterior is 0.377828044428
# The posterior is 0.377828044428
# The posterior is 0.377828044442
# The posterior is 0.377828044429
# The posterior is 0.377807134874
# The posterior is 0.377807134874
# The posterior is 0.377807134875
# The posterior is 0.377807134875
# The posterior is 0.377807134882
# The posterior is 0.3778071349
# The posterior is 0.377807134876
# The posterior is 0.377807134871
# The posterior is 0.377807134874
# The posterior is 0.377807134892
# The posterior is 0.377807134874
# The posterior is 0.377789750931
# The posterior is 0.377789750931
# The posterior is 0.377789750932
# The posterior is 0.377789750931
# The posterior is 0.377789750941
# The posterior is 0.377789750952
# The posterior is 0.377789750932
# The posterior is 0.377789750927
# The posterior is 0.377789750931
# The posterior is 0.377789750948
# The posterior is 0.37778975093
# The posterior is 0.377777656926
# The posterior is 0.377777656926
# The posterior is 0.377777656926
# The posterior is 0.377777656926
# The posterior is 0.377777656938
# The posterior is 0.37777765694
# The posterior is 0.377777656926
# The posterior is 0.377777656921
# The posterior is 0.377777656925
# The posterior is 0.377777656939
# The posterior is 0.377777656924
# The posterior is 0.377765537478
# The posterior is 0.377765537478
# The posterior is 0.377765537478
# The posterior is 0.377765537478
# The posterior is 0.377765537492
# The posterior is 0.377765537487
# The posterior is 0.377765537478
# The posterior is 0.377765537475
# The posterior is 0.377765537478
# The posterior is 0.377765537488
# The posterior is 0.377765537477
# The posterior is 0.37774642641
# The posterior is 0.37774642641
# The posterior is 0.37774642641
# The posterior is 0.37774642641
# The posterior is 0.377746426424
# The posterior is 0.377746426412
# The posterior is 0.37774642641
# The posterior is 0.377746426408
# The posterior is 0.37774642641
# The posterior is 0.377746426414
# The posterior is 0.377746426409
# The posterior is 0.377720428213
# The posterior is 0.377720428213
# The posterior is 0.377720428213
# The posterior is 0.377720428213
# The posterior is 0.377720428225
# The posterior is 0.377720428207
# The posterior is 0.377720428212
# The posterior is 0.377720428213
# The posterior is 0.377720428213
# The posterior is 0.377720428211
# The posterior is 0.377720428213
# The posterior is 0.377707091337
# The posterior is 0.377707091337
# The posterior is 0.377707091338
# The posterior is 0.377707091337
# The posterior is 0.377707091345
# The posterior is 0.377707091331
# The posterior is 0.377707091337
# The posterior is 0.377707091336
# The posterior is 0.377707091337
# The posterior is 0.377707091335
# The posterior is 0.37770709134
# The posterior is 0.377703576569
# The posterior is 0.377703576569
# The posterior is 0.37770357657
# The posterior is 0.37770357657
# The posterior is 0.377703576575
# The posterior is 0.377703576566
# The posterior is 0.377703576569
# The posterior is 0.377703576566
# The posterior is 0.377703576569
# The posterior is 0.377703576569
# The posterior is 0.377703576572
# The posterior is 0.377703029013
# The posterior is 0.377703029013
# The posterior is 0.377703029013
# The posterior is 0.377703029013
# The posterior is 0.377703029017
# The posterior is 0.37770302901
# The posterior is 0.377703029012
# The posterior is 0.377703029009
# The posterior is 0.377703029013
# The posterior is 0.377703029014
# The posterior is 0.377703029015
# The posterior is 0.377702551309
# The posterior is 0.377702551309
# The posterior is 0.377702551309
# The posterior is 0.377702551309
# The posterior is 0.377702551313
# The posterior is 0.377702551307
# The posterior is 0.377702551309
# The posterior is 0.377702551305
# The posterior is 0.377702551309
# The posterior is 0.377702551311
# The posterior is 0.377702551312
# The posterior is 0.377701698846
# The posterior is 0.377701698846
# The posterior is 0.377701698846
# The posterior is 0.377701698846
# The posterior is 0.377701698849
# The posterior is 0.377701698844
# The posterior is 0.377701698845
# The posterior is 0.377701698841
# The posterior is 0.377701698846
# The posterior is 0.377701698849
# The posterior is 0.377701698848
# The posterior is 0.377700139909
# The posterior is 0.377700139909
# The posterior is 0.377700139909
# The posterior is 0.377700139909
# The posterior is 0.377700139912
# The posterior is 0.377700139908
# The posterior is 0.377700139909
# The posterior is 0.377700139903
# The posterior is 0.377700139909
# The posterior is 0.377700139913
# The posterior is 0.377700139911
# The posterior is 0.377697302476
# The posterior is 0.377697302476
# The posterior is 0.377697302476
# The posterior is 0.377697302476
# The posterior is 0.377697302478
# The posterior is 0.377697302475
# The posterior is 0.377697302475
# The posterior is 0.377697302469
# The posterior is 0.377697302476
# The posterior is 0.377697302481
# The posterior is 0.377697302478
# The posterior is 0.377692304989
# The posterior is 0.377692304989
# The posterior is 0.37769230499
# The posterior is 0.377692304989
# The posterior is 0.37769230499
# The posterior is 0.37769230499
# The posterior is 0.377692304989
# The posterior is 0.377692304983
# The posterior is 0.377692304989
# The posterior is 0.377692304996
# The posterior is 0.377692304991
# The posterior is 0.377684264897
# The posterior is 0.377684264897
# The posterior is 0.377684264897
# The posterior is 0.377684264897
# The posterior is 0.377684264896
# The posterior is 0.377684264899
# The posterior is 0.377684264896
# The posterior is 0.37768426489
# The posterior is 0.377684264896
# The posterior is 0.377684264904
# The posterior is 0.377684264897
# The posterior is 0.377675671906
# The posterior is 0.377675671906
# The posterior is 0.377675671906
# The posterior is 0.377675671906
# The posterior is 0.377675671904
# The posterior is 0.377675671909
# The posterior is 0.377675671906
# The posterior is 0.377675671902
# The posterior is 0.377675671906
# The posterior is 0.377675671912
# The posterior is 0.377675671906
# The posterior is 0.37767255843
# The posterior is 0.37767255843
# The posterior is 0.37767255843
# The posterior is 0.37767255843
# The posterior is 0.377672558428
# The posterior is 0.377672558432
# The posterior is 0.37767255843
# The posterior is 0.377672558427
# The posterior is 0.37767255843
# The posterior is 0.377672558436
# The posterior is 0.37767255843
# The posterior is 0.377671212413
# The posterior is 0.377671212413
# The posterior is 0.377671212413
# The posterior is 0.377671212413
# The posterior is 0.377671212413
# The posterior is 0.377671212414
# The posterior is 0.377671212413
# The posterior is 0.377671212413
# The posterior is 0.377671212413
# The posterior is 0.377671212412
# The posterior is 0.377671212413
# The posterior is 0.377670705136
# The posterior is 0.377670705136
# The posterior is 0.377670705137
# The posterior is 0.377670705136
# The posterior is 0.377670705136
# The posterior is 0.377670705136
# The posterior is 0.377670705136
# The posterior is 0.377670705136
# The posterior is 0.377670705136
# The posterior is 0.377670705139
# The posterior is 0.377670705136
# The posterior is 0.377670493667
# The posterior is 0.377670493667
# The posterior is 0.377670493668
# The posterior is 0.377670493667
# The posterior is 0.377670493667
# The posterior is 0.377670493667
# The posterior is 0.377670493667
# The posterior is 0.377670493667
# The posterior is 0.377670493667
# The posterior is 0.377670493668
# The posterior is 0.377670493667
# The posterior is 0.377670469957
# The posterior is 0.377670469957
# The posterior is 0.377670469957
# The posterior is 0.377670469957
# The posterior is 0.377670469957
# The posterior is 0.377670469957
# The posterior is 0.377670469957
# The posterior is 0.377670469957
# The posterior is 0.377670469957
# The posterior is 0.377670469957
# The posterior is 0.377670469957
# The posterior is 0.377670469144
# The posterior is 0.377670469144
# The posterior is 0.377670469144
# The posterior is 0.377670469144
# The posterior is 0.377670469144
# The posterior is 0.377670469144
# The posterior is 0.377670469143
# The posterior is 0.377670469144
# The posterior is 0.377670469144
# The posterior is 0.377670469144
# The posterior is 0.377670469144
# The posterior is 0.377670467818
# The posterior is 0.377670467818
# The posterior is 0.377670467818
# The posterior is 0.377670467818
# The posterior is 0.377670467818
# The posterior is 0.377670467818
# The posterior is 0.377670467817
# The posterior is 0.377670467818
# The posterior is 0.377670467818
# The posterior is 0.377670467818
# The posterior is 0.377670467818
# The posterior is 0.377670465525
# The posterior is 0.377670465525
# The posterior is 0.377670465525
# The posterior is 0.377670465525
# The posterior is 0.377670465525
# The posterior is 0.377670465525
# The posterior is 0.377670465525
# The posterior is 0.377670465525
# The posterior is 0.377670465525
# The posterior is 0.377670465525
# The posterior is 0.377670465525
# The posterior is 0.37767046138
# The posterior is 0.37767046138
# The posterior is 0.37767046138
# The posterior is 0.37767046138
# The posterior is 0.37767046138
# The posterior is 0.37767046138
# The posterior is 0.37767046138
# The posterior is 0.37767046138
# The posterior is 0.37767046138
# The posterior is 0.37767046138
# The posterior is 0.37767046138
# The posterior is 0.377670453742
# The posterior is 0.377670453742
# The posterior is 0.377670453742
# The posterior is 0.377670453742
# The posterior is 0.377670453741
# The posterior is 0.377670453742
# The posterior is 0.377670453741
# The posterior is 0.377670453742
# The posterior is 0.377670453742
# The posterior is 0.377670453742
# The posterior is 0.377670453742
# The posterior is 0.377670439596
# The posterior is 0.377670439596
# The posterior is 0.377670439597
# The posterior is 0.377670439597
# The posterior is 0.377670439596
# The posterior is 0.377670439597
# The posterior is 0.377670439596
# The posterior is 0.377670439597
# The posterior is 0.377670439597
# The posterior is 0.377670439597
# The posterior is 0.377670439596
# The posterior is 0.377670413516
# The posterior is 0.377670413516
# The posterior is 0.377670413516
# The posterior is 0.377670413516
# The posterior is 0.377670413516
# The posterior is 0.377670413516
# The posterior is 0.377670413515
# The posterior is 0.377670413516
# The posterior is 0.377670413516
# The posterior is 0.377670413516
# The posterior is 0.377670413516
# The posterior is 0.377670365968
# The posterior is 0.377670365968
# The posterior is 0.377670365968
# The posterior is 0.377670365968
# The posterior is 0.377670365968
# The posterior is 0.377670365969
# The posterior is 0.377670365968
# The posterior is 0.377670365969
# The posterior is 0.377670365968
# The posterior is 0.377670365969
# The posterior is 0.377670365968
# The posterior is 0.377670280717
# The posterior is 0.377670280717
# The posterior is 0.377670280717
# The posterior is 0.377670280717
# The posterior is 0.377670280716
# The posterior is 0.377670280717
# The posterior is 0.377670280716
# The posterior is 0.377670280717
# The posterior is 0.377670280717
# The posterior is 0.377670280717
# The posterior is 0.377670280717
# The posterior is 0.377670130183
# The posterior is 0.377670130183
# The posterior is 0.377670130183
# The posterior is 0.377670130183
# The posterior is 0.377670130182
# The posterior is 0.377670130184
# The posterior is 0.377670130183
# The posterior is 0.377670130183
# The posterior is 0.377670130183
# The posterior is 0.377670130184
# The posterior is 0.377670130183
# The posterior is 0.377669865717
# The posterior is 0.377669865717
# The posterior is 0.377669865717
# The posterior is 0.377669865717
# The posterior is 0.377669865716
# The posterior is 0.377669865718
# The posterior is 0.377669865717
# The posterior is 0.377669865718
# The posterior is 0.377669865717
# The posterior is 0.377669865718
# The posterior is 0.377669865717
# The posterior is 0.377669395675
# The posterior is 0.377669395675
# The posterior is 0.377669395675
# The posterior is 0.377669395675
# The posterior is 0.377669395673
# The posterior is 0.377669395677
# The posterior is 0.377669395674
# The posterior is 0.377669395675
# The posterior is 0.377669395675
# The posterior is 0.377669395676
# The posterior is 0.377669395674
# The posterior is 0.377668536032
# The posterior is 0.377668536032
# The posterior is 0.377668536032
# The posterior is 0.377668536032
# The posterior is 0.37766853603
# The posterior is 0.377668536035
# The posterior is 0.377668536032
# The posterior is 0.377668536033
# The posterior is 0.377668536032
# The posterior is 0.377668536034
# The posterior is 0.377668536032
# The posterior is 0.377666926094
# The posterior is 0.377666926094
# The posterior is 0.377666926094
# The posterior is 0.377666926094
# The posterior is 0.377666926091
# The posterior is 0.377666926098
# The posterior is 0.377666926093
# The posterior is 0.377666926095
# The posterior is 0.377666926094
# The posterior is 0.377666926096
# The posterior is 0.377666926093
# The posterior is 0.377664029257
# The posterior is 0.377664029257
# The posterior is 0.377664029257
# The posterior is 0.377664029257
# The posterior is 0.377664029252
# The posterior is 0.377664029263
# The posterior is 0.377664029257
# The posterior is 0.37766402926
# The posterior is 0.377664029257
# The posterior is 0.377664029261
# The posterior is 0.377664029257
# The posterior is 0.377660404401
# The posterior is 0.377660404401
# The posterior is 0.377660404401
# The posterior is 0.377660404401
# The posterior is 0.377660404394
# The posterior is 0.377660404409
# The posterior is 0.377660404401
# The posterior is 0.377660404405
# The posterior is 0.377660404401
# The posterior is 0.377660404408
# The posterior is 0.3776604044
# The posterior is 0.377656522717
# The posterior is 0.377656522717
# The posterior is 0.377656522717
# The posterior is 0.377656522717
# The posterior is 0.377656522709
# The posterior is 0.377656522726
# The posterior is 0.377656522716
# The posterior is 0.37765652272
# The posterior is 0.377656522717
# The posterior is 0.377656522723
# The posterior is 0.377656522716
# The posterior is 0.37764922944
# The posterior is 0.37764922944
# The posterior is 0.37764922944
# The posterior is 0.37764922944
# The posterior is 0.377649229433
# The posterior is 0.377649229449
# The posterior is 0.37764922944
# The posterior is 0.377649229443
# The posterior is 0.37764922944
# The posterior is 0.377649229445
# The posterior is 0.377649229439
# The posterior is 0.377636572489
# The posterior is 0.377636572489
# The posterior is 0.37763657249
# The posterior is 0.37763657249
# The posterior is 0.377636572484
# The posterior is 0.377636572498
# The posterior is 0.377636572489
# The posterior is 0.377636572492
# The posterior is 0.377636572489
# The posterior is 0.377636572493
# The posterior is 0.377636572489
# The posterior is 0.37762127118
# The posterior is 0.37762127118
# The posterior is 0.37762127118
# The posterior is 0.37762127118
# The posterior is 0.377621271179
# The posterior is 0.377621271185
# The posterior is 0.37762127118
# The posterior is 0.377621271181
# The posterior is 0.37762127118
# The posterior is 0.377621271181
# The posterior is 0.37762127118
# The posterior is 0.377619314774
# The posterior is 0.377619314774
# The posterior is 0.377619314774
# The posterior is 0.377619314774
# The posterior is 0.377619314773
# The posterior is 0.377619314775
# The posterior is 0.377619314774
# The posterior is 0.377619314774
# The posterior is 0.377619314774
# The posterior is 0.377619314774
# The posterior is 0.377619314773
# The posterior is 0.377618784922
# The posterior is 0.377618784922
# The posterior is 0.377618784922
# The posterior is 0.377618784922
# The posterior is 0.377618784922
# The posterior is 0.377618784923
# The posterior is 0.377618784922
# The posterior is 0.377618784921
# The posterior is 0.377618784922
# The posterior is 0.377618784922
# The posterior is 0.377618784922
# The posterior is 0.377618169917
# The posterior is 0.377618169917
# The posterior is 0.377618169917
# The posterior is 0.377618169917
# The posterior is 0.377618169917
# The posterior is 0.377618169917
# The posterior is 0.377618169917
# The posterior is 0.377618169916
# The posterior is 0.377618169917
# The posterior is 0.377618169916
# The posterior is 0.377618169917
# The posterior is 0.377618134969
# The posterior is 0.377618134969
# The posterior is 0.377618134969
# The posterior is 0.377618134969
# The posterior is 0.377618134969
# The posterior is 0.377618134969
# The posterior is 0.377618134969
# The posterior is 0.377618134969
# The posterior is 0.377618134969
# The posterior is 0.377618134969
# The posterior is 0.377618134969
# The posterior is 0.377618131859
# The posterior is 0.377618131859
# The posterior is 0.377618131859
# The posterior is 0.377618131859
# The posterior is 0.377618131859
# The posterior is 0.377618131859
# The posterior is 0.377618131859
# The posterior is 0.377618131859
# The posterior is 0.377618131859
# The posterior is 0.377618131859
# The posterior is 0.377618131859
# The posterior is 0.377618131481
# The posterior is 0.377618131481
# The posterior is 0.377618131481
# The posterior is 0.377618131482
# The posterior is 0.377618131481
# The posterior is 0.377618131481
# The posterior is 0.377618131481
# The posterior is 0.377618131481
# The posterior is 0.377618131481
# The posterior is 0.377618131481
# The posterior is 0.377618131481
# The posterior is 0.377618130825
# The posterior is 0.377618130825
# The posterior is 0.377618130825
# The posterior is 0.377618130825
# The posterior is 0.377618130825
# The posterior is 0.377618130825
# The posterior is 0.377618130825
# The posterior is 0.377618130825
# The posterior is 0.377618130825
# The posterior is 0.377618130825
# The posterior is 0.377618130825
# The posterior is 0.377618129627
# The posterior is 0.377618129627
# The posterior is 0.377618129627
# The posterior is 0.377618129627
# The posterior is 0.377618129627
# The posterior is 0.377618129627
# The posterior is 0.377618129627
# The posterior is 0.377618129627
# The posterior is 0.377618129627
# The posterior is 0.377618129627
# The posterior is 0.377618129627
# The posterior is 0.377618127414
# The posterior is 0.377618127414
# The posterior is 0.377618127414
# The posterior is 0.377618127414
# The posterior is 0.377618127414
# The posterior is 0.377618127414
# The posterior is 0.377618127414
# The posterior is 0.377618127414
# The posterior is 0.377618127414
# The posterior is 0.377618127414
# The posterior is 0.377618127414
# The posterior is 0.377618123328
# The posterior is 0.377618123328
# The posterior is 0.377618123329
# The posterior is 0.377618123329
# The posterior is 0.377618123328
# The posterior is 0.377618123328
# The posterior is 0.377618123329
# The posterior is 0.377618123328
# The posterior is 0.377618123329
# The posterior is 0.377618123329
# The posterior is 0.377618123328
# The posterior is 0.377618115768
# The posterior is 0.377618115768
# The posterior is 0.377618115768
# The posterior is 0.377618115768
# The posterior is 0.377618115768
# The posterior is 0.377618115768
# The posterior is 0.377618115768
# The posterior is 0.377618115768
# The posterior is 0.377618115768
# The posterior is 0.377618115768
# The posterior is 0.377618115768
# The posterior is 0.377618102136
# The posterior is 0.377618102136
# The posterior is 0.377618102136
# The posterior is 0.377618102136
# The posterior is 0.377618102136
# The posterior is 0.377618102136
# The posterior is 0.377618102136
# The posterior is 0.377618102136
# The posterior is 0.377618102136
# The posterior is 0.377618102136
# The posterior is 0.377618102136
# The posterior is 0.377618077864
# The posterior is 0.377618077864
# The posterior is 0.377618077864
# The posterior is 0.377618077864
# The posterior is 0.377618077863
# The posterior is 0.377618077863
# The posterior is 0.377618077864
# The posterior is 0.377618077863
# The posterior is 0.377618077864
# The posterior is 0.377618077864
# The posterior is 0.377618077863
# The posterior is 0.377618035964
# The posterior is 0.377618035964
# The posterior is 0.377618035964
# The posterior is 0.377618035964
# The posterior is 0.377618035964
# The posterior is 0.377618035964
# The posterior is 0.377618035964
# The posterior is 0.377618035964
# The posterior is 0.377618035964
# The posterior is 0.377618035965
# The posterior is 0.377618035964
# The posterior is 0.377617964757
# The posterior is 0.377617964757
# The posterior is 0.377617964757
# The posterior is 0.377617964757
# The posterior is 0.377617964757
# The posterior is 0.377617964757
# The posterior is 0.377617964757
# The posterior is 0.377617964756
# The posterior is 0.377617964757
# The posterior is 0.377617964758
# The posterior is 0.377617964757
# The posterior is 0.377617842984
# The posterior is 0.377617842984
# The posterior is 0.377617842985
# The posterior is 0.377617842985
# The posterior is 0.377617842984
# The posterior is 0.377617842984
# The posterior is 0.377617842984
# The posterior is 0.377617842984
# The posterior is 0.377617842984
# The posterior is 0.377617842986
# The posterior is 0.377617842984
# The posterior is 0.377617630851
# The posterior is 0.377617630851
# The posterior is 0.377617630851
# The posterior is 0.377617630852
# The posterior is 0.377617630851
# The posterior is 0.37761763085
# The posterior is 0.377617630851
# The posterior is 0.37761763085
# The posterior is 0.377617630851
# The posterior is 0.377617630853
# The posterior is 0.377617630851
# The posterior is 0.377617252599
# The posterior is 0.377617252599
# The posterior is 0.377617252599
# The posterior is 0.377617252599
# The posterior is 0.377617252599
# The posterior is 0.377617252598
# The posterior is 0.377617252599
# The posterior is 0.377617252598
# The posterior is 0.377617252599
# The posterior is 0.377617252602
# The posterior is 0.377617252599
# The posterior is 0.377616573634
# The posterior is 0.377616573634
# The posterior is 0.377616573634
# The posterior is 0.377616573634
# The posterior is 0.377616573633
# The posterior is 0.377616573632
# The posterior is 0.377616573634
# The posterior is 0.377616573632
# The posterior is 0.377616573634
# The posterior is 0.377616573637
# The posterior is 0.377616573633
# The posterior is 0.377615345908
# The posterior is 0.377615345908
# The posterior is 0.377615345908
# The posterior is 0.377615345908
# The posterior is 0.377615345907
# The posterior is 0.377615345906
# The posterior is 0.377615345908
# The posterior is 0.377615345906
# The posterior is 0.377615345908
# The posterior is 0.377615345912
# The posterior is 0.377615345907
# The posterior is 0.37761312159
# The posterior is 0.37761312159
# The posterior is 0.37761312159
# The posterior is 0.37761312159
# The posterior is 0.377613121589
# The posterior is 0.377613121588
# The posterior is 0.37761312159
# The posterior is 0.377613121587
# The posterior is 0.37761312159
# The posterior is 0.377613121596
# The posterior is 0.377613121589
# The posterior is 0.377609130839
# The posterior is 0.377609130839
# The posterior is 0.377609130839
# The posterior is 0.377609130839
# The posterior is 0.377609130838
# The posterior is 0.377609130835
# The posterior is 0.377609130839
# The posterior is 0.377609130834
# The posterior is 0.377609130839
# The posterior is 0.377609130846
# The posterior is 0.377609130838
# The posterior is 0.377601990959
# The posterior is 0.377601990959
# The posterior is 0.377601990959
# The posterior is 0.37760199096
# The posterior is 0.377601990958
# The posterior is 0.377601990955
# The posterior is 0.377601990959
# The posterior is 0.377601990954
# The posterior is 0.377601990959
# The posterior is 0.377601990968
# The posterior is 0.377601990958
# The posterior is 0.377589314146
# The posterior is 0.377589314146
# The posterior is 0.377589314146
# The posterior is 0.377589314147
# The posterior is 0.377589314145
# The posterior is 0.377589314141
# The posterior is 0.377589314146
# The posterior is 0.37758931414
# The posterior is 0.377589314146
# The posterior is 0.377589314156
# The posterior is 0.377589314145
# The posterior is 0.377567408843
# The posterior is 0.377567408843
# The posterior is 0.377567408843
# The posterior is 0.377567408843
# The posterior is 0.377567408842
# The posterior is 0.377567408836
# The posterior is 0.377567408843
# The posterior is 0.377567408836
# The posterior is 0.377567408843
# The posterior is 0.377567408852
# The posterior is 0.377567408841
# The posterior is 0.377533611909
# The posterior is 0.377533611909
# The posterior is 0.37753361191
# The posterior is 0.37753361191
# The posterior is 0.377533611909
# The posterior is 0.377533611901
# The posterior is 0.377533611909
# The posterior is 0.377533611901
# The posterior is 0.377533611909
# The posterior is 0.377533611918
# The posterior is 0.377533611908
# The posterior is 0.377577972824
# The posterior is 0.377577972824
# The posterior is 0.377577972824
# The posterior is 0.377577972824
# The posterior is 0.377577972824
# The posterior is 0.377577972808
# The posterior is 0.377577972831
# The posterior is 0.377577972821
# The posterior is 0.377577972824
# The posterior is 0.377577972814
# The posterior is 0.377577972823
# The posterior is 0.377521230476
# The posterior is 0.377521230476
# The posterior is 0.377521230476
# The posterior is 0.377521230476
# The posterior is 0.377521230476
# The posterior is 0.377521230467
# The posterior is 0.377521230477
# The posterior is 0.377521230469
# The posterior is 0.377521230476
# The posterior is 0.377521230483
# The posterior is 0.377521230475
# The posterior is 0.377502774024
# The posterior is 0.377502774024
# The posterior is 0.377502774024
# The posterior is 0.377502774024
# The posterior is 0.377502774021
# The posterior is 0.377502774018
# The posterior is 0.377502774024
# The posterior is 0.377502774014
# The posterior is 0.377502774024
# The posterior is 0.377502774043
# The posterior is 0.377502774022
# The posterior is 0.377501046324
# The posterior is 0.377501046324
# The posterior is 0.377501046324
# The posterior is 0.377501046324
# The posterior is 0.37750104633
# The posterior is 0.377501046314
# The posterior is 0.377501046323
# The posterior is 0.377501046325
# The posterior is 0.377501046324
# The posterior is 0.377501046293
# The posterior is 0.377501046323
# The posterior is 0.377493014207
# The posterior is 0.377493014207
# The posterior is 0.377493014207
# The posterior is 0.377493014207
# The posterior is 0.377493014208
# The posterior is 0.377493014199
# The posterior is 0.377493014207
# The posterior is 0.377493014202
# The posterior is 0.377493014207
# The posterior is 0.377493014206
# The posterior is 0.377493014206
# The posterior is 0.377480099318
# The posterior is 0.377480099318
# The posterior is 0.377480099318
# The posterior is 0.377480099318
# The posterior is 0.377480099314
# The posterior is 0.377480099316
# The posterior is 0.377480099318
# The posterior is 0.377480099312
# The posterior is 0.377480099318
# The posterior is 0.377480099335
# The posterior is 0.377480099316
# The posterior is 0.377466738914
# The posterior is 0.377466738914
# The posterior is 0.377466738914
# The posterior is 0.377466738914
# The posterior is 0.377466738909
# The posterior is 0.377466738914
# The posterior is 0.377466738913
# The posterior is 0.377466738909
# The posterior is 0.377466738914
# The posterior is 0.377466738933
# The posterior is 0.377466738911
# The posterior is 0.377440915535
# The posterior is 0.377440915535
# The posterior is 0.377440915535
# The posterior is 0.377440915535
# The posterior is 0.377440915531
# The posterior is 0.377440915538
# The posterior is 0.377440915534
# The posterior is 0.377440915533
# The posterior is 0.377440915535
# The posterior is 0.377440915551
# The posterior is 0.377440915532
# The posterior is 0.377470120499
# The posterior is 0.377470120499
# The posterior is 0.377470120499
# The posterior is 0.377470120499
# The posterior is 0.377470120516
# The posterior is 0.377470120505
# The posterior is 0.377470120499
# The posterior is 0.377470120523
# The posterior is 0.377470120499
# The posterior is 0.377470120433
# The posterior is 0.377470120504
# The posterior is 0.377406482154
# The posterior is 0.377406482154
# The posterior is 0.377406482154
# The posterior is 0.377406482154
# The posterior is 0.377406482156
# The posterior is 0.377406482161
# The posterior is 0.377406482154
# The posterior is 0.377406482162
# The posterior is 0.377406482154
# The posterior is 0.377406482144
# The posterior is 0.377406482152
# The posterior is 0.377591849425
# The posterior is 0.377591849425
# The posterior is 0.377591849425
# The posterior is 0.377591849425
# The posterior is 0.37759184945
# The posterior is 0.377591849424
# The posterior is 0.377591849427
# The posterior is 0.377591849453
# The posterior is 0.377591849426
# The posterior is 0.377591849334
# The posterior is 0.377591849441
# The posterior is 0.377396295614
# The posterior is 0.377396295614
# The posterior is 0.377396295614
# The posterior is 0.377396295614
# The posterior is 0.377396295619
# The posterior is 0.37739629562
# The posterior is 0.377396295614
# The posterior is 0.377396295625
# The posterior is 0.377396295614
# The posterior is 0.377396295591
# The posterior is 0.377396295613
# The posterior is 0.377378815464
# The posterior is 0.377378815464
# The posterior is 0.377378815464
# The posterior is 0.377378815464
# The posterior is 0.377378815469
# The posterior is 0.377378815469
# The posterior is 0.377378815464
# The posterior is 0.377378815474
# The posterior is 0.377378815464
# The posterior is 0.377378815443
# The posterior is 0.377378815464
# The posterior is 0.37735393471
# The posterior is 0.37735393471
# The posterior is 0.37735393471
# The posterior is 0.37735393471
# The posterior is 0.377353934713
# The posterior is 0.377353934713
# The posterior is 0.37735393471
# The posterior is 0.377353934715
# The posterior is 0.37735393471
# The posterior is 0.377353934698
# The posterior is 0.37735393471
# The posterior is 0.37734789766
# The posterior is 0.37734789766
# The posterior is 0.37734789766
# The posterior is 0.37734789766
# The posterior is 0.377347897661
# The posterior is 0.37734789766
# The posterior is 0.377347897661
# The posterior is 0.377347897661
# The posterior is 0.37734789766
# The posterior is 0.377347897658
# The posterior is 0.37734789766
# The posterior is 0.377347765568
# The posterior is 0.377347765568
# The posterior is 0.377347765568
# The posterior is 0.377347765569
# The posterior is 0.37734776557
# The posterior is 0.377347765567
# The posterior is 0.377347765568
# The posterior is 0.377347765568
# The posterior is 0.377347765569
# The posterior is 0.377347765565
# The posterior is 0.377347765569
# The posterior is 0.377346618784
# The posterior is 0.377346618784
# The posterior is 0.377346618784
# The posterior is 0.377346618784
# The posterior is 0.377346618785
# The posterior is 0.377346618783
# The posterior is 0.377346618784
# The posterior is 0.377346618784
# The posterior is 0.377346618784
# The posterior is 0.377346618781
# The posterior is 0.377346618784
# The posterior is 0.377346473061
# The posterior is 0.377346473061
# The posterior is 0.377346473061
# The posterior is 0.377346473061
# The posterior is 0.377346473061
# The posterior is 0.377346473061
# The posterior is 0.377346473061
# The posterior is 0.377346473061
# The posterior is 0.377346473061
# The posterior is 0.377346473059
# The posterior is 0.377346473061
# The posterior is 0.377346382146
# The posterior is 0.377346382146
# The posterior is 0.377346382146
# The posterior is 0.377346382146
# The posterior is 0.377346382147
# The posterior is 0.377346382146
# The posterior is 0.377346382146
# The posterior is 0.377346382147
# The posterior is 0.377346382146
# The posterior is 0.377346382145
# The posterior is 0.377346382147
# The posterior is 0.377346354777
# The posterior is 0.377346354777
# The posterior is 0.377346354777
# The posterior is 0.377346354777
# The posterior is 0.377346354777
# The posterior is 0.377346354777
# The posterior is 0.377346354777
# The posterior is 0.377346354777
# The posterior is 0.377346354777
# The posterior is 0.377346354777
# The posterior is 0.377346354777
# The posterior is 0.377346349666
# The posterior is 0.377346349666
# The posterior is 0.377346349666
# The posterior is 0.377346349666
# The posterior is 0.377346349666
# The posterior is 0.377346349666
# The posterior is 0.377346349666
# The posterior is 0.377346349666
# The posterior is 0.377346349666
# The posterior is 0.377346349666
# The posterior is 0.377346349666
# Optimization terminated successfully.
#          Current function value: 0.377346
#          Iterations: 105
#          Function evaluations: 1232
#          Gradient evaluations: 112

# %% [markdown]
# You can see that the fitting doesn't work very well, because the fitting keeps jumping out of the regions allowed by the prior. We might need to change those priors, but for now, let's see what happens when we run emcee.

# %%
print(results)
popt = results[0]
print("popt: " + str(popt))
post_opt = results[1]
covar = results[2]
#print(covar)
fit_profile = ellipse_model(xdata, *popt)

fig = plt.figure(figsize=(10,20))
plt.subplot(2,1,1)
plt.imshow(sb_data)
plt.colorbar()
plt.subplot(2,1,2)
plt.imshow(fit_profile)
plt.colorbar()
# Out:
# (array([  3.81292224e+02,   3.53049463e+02,  -9.30810627e-02,
#         -2.72071022e-01,   5.17292144e+00,  -1.44432891e+01,
#          9.49451929e+01,   7.44847974e-01,  -1.88698868e+01]), 0.37734634966585906, array([ -1.36718154e-06,   5.28991222e-07,  -2.87964940e-06,
#         -1.19581819e-06,   8.56816769e-08,  -3.91155481e-07,
#          2.09733844e-06,   3.27825546e-07,   7.45058060e-09]), array([[  4.65432518e+05,   6.88410268e+05,   2.16469992e+03,
#           5.48538182e+03,  -2.45997801e+03,  -1.76280261e+03,
#           1.24719513e+05,  -4.73688705e+02,  -3.50843500e+03],
#        [  6.88410268e+05,   1.01827896e+06,   3.21522079e+03,
#           8.11558887e+03,  -3.46837306e+03,  -2.62523365e+03,
#           1.84465786e+05,  -6.95215007e+02,  -5.16306245e+03],
#        [  2.16469992e+03,   3.21522079e+03,   1.16143381e+02,
#           2.96552534e+01,   2.27093799e+01,  -3.79767914e+01,
#           5.78835485e+02,   2.00138152e+01,  -1.31563018e+01],
#        [  5.48538182e+03,   8.11558887e+03,   2.96552534e+01,
#           9.49700342e+01,  -1.96688264e+01,  -3.11804584e+01,
#           1.46989694e+03,  -1.54613980e+01,  -7.97504014e+01],
#        [ -2.45997801e+03,  -3.46837306e+03,   2.27093799e+01,
#          -1.96688264e+01,   4.64273892e+02,  -4.51959930e+01,
#          -6.70503907e+02,   1.30123111e+01,   7.13344479e+01],
#        [ -1.76280261e+03,  -2.62523365e+03,  -3.79767914e+01,
#          -3.11804584e+01,  -4.51959930e+01,   2.23179006e+02,
#          -4.71513624e+02,   5.89924684e+01,   2.33018203e+02],
#        [  1.24719513e+05,   1.84465786e+05,   5.78835485e+02,
#           1.46989694e+03,  -6.70503907e+02,  -4.71513624e+02,
#           3.34218226e+04,  -1.28087967e+02,  -9.48353540e+02],
#        [ -4.73688705e+02,  -6.95215007e+02,   2.00138152e+01,
#          -1.54613980e+01,   1.30123111e+01,   5.89924684e+01,
#          -1.28087967e+02,   4.17324428e+01,   1.94327581e+02],
#        [ -3.50843500e+03,  -5.16306245e+03,  -1.31563018e+01,
#          -7.97504014e+01,   7.13344479e+01,   2.33018203e+02,
#          -9.48353540e+02,   1.94327581e+02,   1.72531155e+03]]), 1232, 112, 0)
# popt: [  3.81292224e+02   3.53049463e+02  -9.30810627e-02  -2.72071022e-01
#    5.17292144e+00  -1.44432891e+01   9.49451929e+01   7.44847974e-01
#   -1.88698868e+01]
# <matplotlib.colorbar.Colorbar instance at 0x11b693ab8>

# %%
import emcee

## number of walkers in emcee
## should be large (>100)
nwalkers = 100

### number of dimensions for the Gaussian seeds (= number of parameters)
ndim = len(popt)
        

#x, cp_x, cp_y, q, a, phi, logScool, rcool, betacool, logbackground

#covar_guess = np.array([20., 20., 0.01, 10., 0.2, 2.0, 10., 0.1, 2.])

### sample random starting positions for each of the walkers
p0 = [np.random.multivariate_normal(results[0], results[3]) for i in xrange(nwalkers)]

### initialize sampler
sampler = emcee.EnsembleSampler(nwalkers, ndim, lpost)

### run burn-in phase and reset sampler
burnin_samples = 300
pos, prob, state = sampler.run_mcmc(p0, burnin_samples)
sampler.reset()


### run actual MCMCs
niter = 100
sampler.run_mcmc(pos, niter, rstate0=state)

### list of all samples stored in flatchain
mcall = sampler.flatchain

### print meanacceptance rate for all walkers and autocorrelation times
print("The ensemble acceptance rate is: " + str(np.mean(sampler.acceptance_fraction)))
L = np.mean(sampler.acceptance_fraction)*len(mcall)
acceptance = np.mean(sampler.acceptance_fraction)
#try:
#    self.acor = sampler.acor
#    print("The autocorrelation times are: " +  str(sampler.acor))
#except ImportError:
#    print("You can install acor: http://github.com/dfm/acor")
#    self.acor = None
#except RuntimeError:
#    print("D was negative. No clue why that's the case! Not computing autocorrelation time ...")
#    self.acor = None
#except:
#    print("Autocorrelation time calculation failed due to an unknown error: " + sys.exc_info()[0] + ". Not computing autocorrelation time.")
#    self.acor = None
# Out:
# -c:11: RuntimeWarning: overflow encountered in power
# -c:51: RuntimeWarning: invalid value encountered in multiply
# -c:10: RuntimeWarning: overflow encountered in square
# -c:7: RuntimeWarning: overflow encountered in exp
# -c:11: RuntimeWarning: overflow encountered in multiply
# -c:11: RuntimeWarning: invalid value encountered in multiply
# -c:6: RuntimeWarning: overflow encountered in exp
# -c:5: RuntimeWarning: overflow encountered in exp
# -c:51: RuntimeWarning: divide by zero encountered in log
# -c:10: RuntimeWarning: divide by zero encountered in divide
# -c:10: RuntimeWarning: overflow encountered in divide
# The ensemble acceptance rate is: 0.3348

# %%
fig = plt.figure(figsize=(10, 30))
for i in range(9):
    plt.subplot(9,1,(i+1))
    plt.plot(sampler.chain[:,:,i])
    plt.yscale("log")
